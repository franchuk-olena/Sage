# %% [markdown]
# # Лабораторна робота 6
#
# ## Завдання 1
#
# В групі рухів правильного восьмикутника задайте циклічну підгрупу порядку 4. Побудуйте для неї ліві і праві класи суміжності та перевірте чи буде ця група нормальною.

# %%
D8 = DihedralGroup(8)
a = D8('(1,3,5,7)(2,4,6,8)')
H = D8.subgroup([a])
print(H.order())

#праві і ліві класи суміжності
print("Right cosets:")
right_cosets = D8.cosets(H, side='right')
print(right_cosets)

print("Left cosets:")
left_cosets = D8.cosets(H, side='left')
print(left_cosets)

sorted_right_cosets = sorted([sorted(coset) for coset in right_cosets])
sorted_left_cosets = sorted([sorted(coset) for coset in left_cosets])

is_normal = sorted_right_cosets == sorted_left_cosets
print("Is the subgroup normal?", is_normal)
# Out:
# Subgroup generated by [(1,6)(2,7)(3,8)(4,9)(5,10), (1,7)(2,6)(3,5)(8,10)] of (Dihedral group of order 20 as a permutation group)

# %% [markdown]
# ## Завдання 2
#
# Переберіть всі підгрупи знакозмінної групи $A_5$. Перевірте всі на нормальність. Порівняйте час роботи з методом `.is_simple` для групи $A_5$.

# %%
import time
from sage.groups.perm_gps.permgroup_named import AlternatingGroup

A5 = AlternatingGroup(5)
start_time = time.time()

#перевірка нормальності підгрупи
def is_normal(subgroup, group) -> bool: 
    return group.cosets(subgroup, side='right') == group.cosets(subgroup, side='left')

#перевірка простоти групи
def simple_check(group) -> bool:
    trivial_subgroup = group.subgroups()[0]  # Тривіальна підгрупа
    for subgroup in group.subgroups():
        if subgroup.order() not in [1, group.order()] and is_normal(subgroup, group):
            return False 
    return True

print(simple_check(A5))
end_time = time.time()
print(f"My method {end_time - start_time:.4f} seconds")


start_time = time.time()
print(A5.is_simple())
end_time = time.time()
print(f"Built-in method {end_time - start_time:.4f} seconds")

# %% [markdown]
# ## Завдання 3
#
# Задайте кілька діедральних груп $D_n$ для різних $n$. Як варіант, переберіть n в межах $3 \le n \le 100$. Для кожної діедральної групи побудуйте __список порядків нормальних підгруп__ (методом `normal_subgroups`). Знайдіть закономірність і виведіть гіпотезу.
#
# Спрогнозуйте скільки нормальних підгруп має група $D_{470448}$ __без виводу всіх за допомогою Sage__. _Опишіть_ всі нормальні підгрупи групи $D_{470448}$.

# %%
from sage.groups.perm_gps.permgroup_named import DihedralGroup

selected_n = [4, 25, 70]

normal_subgroups_orders = {}

for n in selected_n:
    D_n = DihedralGroup(n)
    normal_subgroups = D_n.normal_subgroups()
    orders = [H.order() for H in normal_subgroups]
    normal_subgroups_orders[n] = orders
for n, orders in normal_subgroups_orders.items():
    print(f"D{n}: Normal subgroup orders = {orders}")

# %% [markdown]
# Гіпотеза :
# Залежно від значення 𝑛, кількість нормальних підгруп і їх порядки можуть бути різними. В цілому, для кожної діедральної групи 𝐷𝑛 порядок нормальних підгруп буде дільником 𝑛 або 2𝑛. У результаті ми можемо зробити припущення, що для парних 𝑛 нормальні підгрупи включатимуть порядки 1, 2, 𝑛
# 1,2,n, і для непарних 𝑛 будуть порядки 1 і 2𝑛.

# %% [markdown]
# Крок 1:
# $D_{470448}$:
# Як ми бачили з попередніх прикладів, для діедральних груп $D_{n}$, кількість нормальних підгруп залежить від значення 𝑛.
#
# Якщо 𝑛 — парне число, то група $D_{n}$ має:
#
# Тривіальну підгрупу порядку 1.
# Підгрупу з порядком 2, що складається з відображень.
# Підгрупу порядку 𝑛, яка включає всі обертальні елементи.
# Повну групу $D_{n}$ з порядком 2𝑛.
# Якщо 𝑛 непарне, то зазвичай нормальні підгрупи мають порядки 1 і 2𝑛, а також група сама є простою, оскільки непарні діедральні групи не мають підгрупи порядку 𝑛.
#
#
#
# Крок 2:
# Прогноз для $D_{470448}$:
# Оскільки 470448 — парне число, застосуємо попередні закономірності:
# Тривіальна підгрупа: Підгрупа порядку 1.
# Підгрупа з порядком 2: Підгрупа, що містить лише відображення.
# Підгрупа з порядком 470448: Підгрупа, що складається з усіх обертальних елементів групи.
# Повна група 𝐷470448
#
# Таким чином, для $D_{470448}$ ми прогнозуємо 4 нормальні підгрупи:
# Тривіальна підгрупа з порядком 1.
# Підгрупа з порядком 2.
# Підгрупа з порядком 470448.
# Повна група $D_{470448}$.
#
#
#
# Крок 3:
# Опис нормальних підгруп
# Тривіальна підгрупа: Це група, що містить лише одиничний елемент групи. Вона є нормальною у будь-якій групі.
#
# Підгрупа з порядком 2: Це підгрупа, що містить лише елементи відображення (рефлекси). Вона містить один елемент порядку 2 і одиничний елемент.
#
# Підгрупа з порядком 470448: Це підгрупа, яка включає лише обертальні елементи групи $D_{470448}$, тобто всі елементи, які є обертами, але без відображень.
#
# Повна група $D_{470448}$: Вся група $D_{470448}$ є нормальною підгрупою самою собою. Вона має порядок 940896, оскільки група є діедральною і містить обертальні елементи і відображення.

# %% [markdown]
# ## Завдання 4
#
# На сайті https://brauer.maths.qmul.ac.uk/Atlas/v3/spor/HS в секції `Representations of HS : Number of Points 100` знайдіть у форматі GAP генератори $G = \langle a, b \rangle$. Задайте їх як елементи групи $S_{100}$ і породіть ними підгрупу $G$. Це так звана Higman-Sims група. Виведіть її порядок і знайдіть нормальні підгрупи. Зробіть висновки.

# %%
S100 = SymmetricGroup(100)
a11 = [(1,60),(2,72),(3,81),(4,43),(5,11),(6,87),(7,34),(9,63),(12,46),(13,28),(14,71),
     (15,42),(16,97),(18,57),(19,52),(21,32),(23,47),(24,54),(25,83),(26,78),(29,89),
     (30,39),(33,61),(35,56),(37,67),(44,76),(45,88),(48,59),(49,86),(50,74),(51,66),
     (53,99),(55,75),(62,73),(65,79),(68,82),(77,92),(84,90),(85,98),(94,100)]
a21 = [(1,86,13,10,47),(2,53,30,8,38),(3,40,48,25,17),(4,29,92,88,43),(5,98,66,54,
     65),(6,27,51,73,24),(7,83,16,20,28),(9,23,89,95,61),(11,42,46,91,32),(12,14,
     81,55,68),(15,90,31,56,37),(18,69,45,84,76),(19,59,79,35,93),(21,22,64,39,
     100),(26,58,96,85,77),(33,52,94,75,44),(34,62,87,78,50),(36,82,60,74,72),(41,80,70,49,67),(57,63,71,99,97)]

G = S100.subgroup([a11, a21])
print(G.order())
print(G.is_simple())
for normal_subgroup in G.normal_subgroups():
    print(normal_subgroup)
    print("--------------------------")
G.structure_description()

# %% [markdown]
# Порядок: ми отримаємо порядок Higman-Sims групи, який повинен бути 44352000.
